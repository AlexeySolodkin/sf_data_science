# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
tree = ET.parse('data/menu.xml')

# %%
root = tree.getroot()
print(root)
# Out:
# <Element 'menu' at 0x0000026EBC267C20>

# %%
list(root)
# Out:
# [<Element 'dish' at 0x0000026EBC267EA0>,
#  <Element 'dish' at 0x0000026EBC2EB2C0>]

# %%
list(root[1])
# Out:
# [<Element 'price' at 0x0000026EBC2EB1D0>,
#  <Element 'weight' at 0x0000026EBC2EB180>,
#  <Element 'class' at 0x0000026EBC2EB130>]

# %%
root[0].attrib
# Out:
# {'name': 'Кура'}

# %%
int(root[0][0].text)
# Out:
# 40

# %%
root.tag
# Out:
# 'menu'

# %%
 root[0][2]
# Out:
# <Element 'class' at 0x0000026EBC2EB360>

# %%
for dish in root:
    for param in dish:
        print(dish.attrib['name'], param.tag, param.text)
    print()
# Out:
# Кура price 40
# Кура weight 300
# Кура class Мясо
#
# Греча price 20
# Греча weight 200
# Греча class Крупа

# %%
column_names = ['name', 'price', 'weight', 'class']
df = pd.DataFrame(columns=column_names)

for dish in root:
    row = [dish.attrib['name'], dish[0].text, dish[1].text, dish[2].text]
    df = df.append(pd.Series(row, index=column_names), ignore_index=True)

df
# Out:
#     name price weight  class
# 0   Кура    40    300   Мясо
# 1  Греча    20    200  Крупа

# %%
new_root = ET.Element('menu')
new_root
# Out:
# <Element 'menu' at 0x0000026EBE4CB3B0>

# %%
dish1 = ET.SubElement(new_root, 'dish', name='Кура')
dish2 = ET.SubElement(new_root, 'dish', name='Греча')

list(new_root)
# Out:
# [<Element 'dish' at 0x0000026EBE4CB540>,
#  <Element 'dish' at 0x0000026EBE4CB590>]

# %%
price1 = ET.SubElement(dish1, "price").text = "40"
weight1 = ET.SubElement(dish1, "weight").text = "300"
class1 = ET.SubElement(dish1, "class").text = "Мясо"
display(list(dish1))

price2 = ET.SubElement(dish2, "price").text = "20"
weight2 = ET.SubElement(dish2, "weight").text = "200"
class2 = ET.SubElement(dish2, "class").text = "Крупа"
display(list(dish2))
# Out:
# [<Element 'price' at 0x0000026EBE4CB270>,
#  <Element 'weight' at 0x0000026EBE518EA0>,
#  <Element 'class' at 0x0000026EBE52DD10>]
# [<Element 'price' at 0x0000026EBE4A6EA0>,
#  <Element 'weight' at 0x0000026EBE52DDB0>,
#  <Element 'class' at 0x0000026EBE52DD60>]

# %%
for dish in new_root:
    for param in dish:
        print(dish.attrib['name'], param.tag, param.text)
    print()
# Out:
# Кура price 40
# Кура weight 300
# Кура class Мясо
#
# Греча price 20
# Греча weight 200
# Греча class Крупа

# %%
new_root_string = ET.tostring(new_root)
with open("data/new_menu.xml", "wb") as f:
    f.write(new_root_string) # проблемы с кодировкой

# %%
ET.ElementTree(new_root).write('new_menu_good.xml', encoding="utf-8") # исправление проблемы с кодировкой
