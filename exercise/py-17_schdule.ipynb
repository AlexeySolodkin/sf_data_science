# %%
import schedule # Импортируем модуль schedule
import time

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %%
schedule.every(2).minutes.do(task)
# Out:
# Every 2 minutes do task() (last run: [never], next run: 2021-12-15 08:51:47)

# %%
while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1a9f2606e963> in <module>
#       1 while True:
#       2     schedule.run_pending()
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:
